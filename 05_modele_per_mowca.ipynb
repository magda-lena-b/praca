# %%
import re
import pandas as pd
import funcs 
import importlib
import unicodecsv as csv
import pickle
import random
from timeit import default_timer as timer
from datetime import datetime, timedelta
import ng_models
import matplotlib.pyplot as plt


# %matplotlib notebook
importlib.reload(funcs)
importlib.reload(ng_models)
# Out:
# <module 'ng_models' from 'C:\\Users\\Mag\\Documents\\_projekty\\praca\\ng_models.py'>

# %%
sp_joined = pd.read_csv('00_dane/sp_joined.csv',  sep='|', encoding='UTF-8')

# %%
sp_joined.head(10)
# Out:
#    Unnamed: 0       date_                  author_final  \
# 0           0  01-02-1992         Aleksander Bentkowski
# 1           1  01-02-1992        Aleksander Kwaśniewski
# 2           2  01-02-1992               Alojzy Pietrzyk
# 3           3  01-02-1992             Alojzy Szablewski
# 4           4  01-02-1992            Andrzej Baraniecki
# 5           5  01-02-1992               Andrzej Potocki
# 6           6  01-02-1992  Andrzej Tadeusz Mazurkiewicz
# 7           7  01-02-1992              Andrzej Urbański
# 8           8  01-02-1992               Andrzej Wojtyła
# 9           9  01-02-1992              Andrzej Zarębski
#
#                                         speech_title  \
# 0  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 1  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 2  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 3                                      Oświadczenia.
# 4  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 5  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 6  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 7  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 8  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
# 9  Sprawozdanie Komisji Sprawiedliwości oraz Komi...
#
#                                           speech_raw  \
# 0   Panie Marszałku! Wysoki Sejmie! Chciałbym kil...
# 1   Panie Marszałku! Wysoka Izbo! Przysłuchując s...
# 2   Panie Marszałku! Wysoka Izbo! Różne przebyliś...
# 3   Panie Marszałku! Wysoka Izbo! Wszystkim nam b...
# 4   Wysoka Izbo! Z brzmienia pkt. 1 projektu uchw...
# 5   Panie Marszałku! Wysoka Izbo! W związku z tym...
# 6   Andrzej Tadeusz Mazurkiewicz, Konfederacja Po...
# 7   Panie Marszałku! Panie! Panowie! Parlamentarn...
# 8   Panie Marszałku! Wysoka Izbo! W nocy z 12 na ...
# 9   Panie Marszałku! Panie i Panowie Posłowie! Kl...
#
#                                         speech_rawer  liczba_sl_raw  \
# 0   Chciałbym kilka zdań powiedzieć na temat skut...            851
# 1   Przysłuchując się tej bardzo emocjonalnej, dł...            919
# 2   Różne przebyliśmy drogi, żeby tu dzisiaj powi...            329
# 3   Wszystkim nam bardzo zależy na tym, aby urato...            611
# 4   Z brzmienia pkt. 1 projektu uchwały odczytuję...            130
# 5   W związku z tym chcę zapytać panią Ponieważ S...             39
# 6   Andrzej Tadeusz Mazurkiewicz, Konfederacja Po...            211
# 7     Parlamentarny Klub Porozumienia Centrum pop...            736
# 8   W nocy z 12 na 13 grudnia 1981 r. ówczesne ko...            462
# 9   Klub Liberalno-Demokratyczny popiera projekt ...            793
#
#    liczba_sl_rawer
# 0              845
# 1              915
# 2              325
# 3              607
# 4              128
# 5               33
# 6              207
# 7              732
# 8              450
# 9              787

# %% [markdown]
# #### Którzy politycy mają nawięcej treści?

# %%
ag=sp_joined.groupby('author_final').agg({'liczba_sl_raw': sum, 'date_': 'count'}).reset_index()

# %%
sp_joined[sp_joined.author_final=='Zygmunt Kufel']
# Out:
#         Unnamed: 0       date_   author_final  \
# 30196        30196  07-11-1992  Zygmunt Kufel
# 43099        43099  09-12-1992  Zygmunt Kufel
# 125034      125034  24-07-1992  Zygmunt Kufel
#
#                                              speech_title  \
# 30196   Pierwsze czytanie rządowego projektu ustawy o ...
# 43099   Pierwsze czytanie przedstawionego przez Komisj...
# 125034  Pierwsze czytanie poselskich projektów ustaw: ...
#
#                                                speech_raw  \
# 30196    Panie Marszałku! Wysoki Sejmie! Wobec głosów ...
# 43099    Panie Marszałku! Wysoki Sejmie! W historii na...
# 125034   Panie Marszałku! Wysoki Sejmie! Znikomość cza...
#
#                                              speech_rawer  liczba_sl_raw  \
# 30196    Wobec głosów kwestionujących celowość uznania...            628
# 43099    W historii naszego państwa jego granice nie z...            570
# 125034   Znikomość czasu nie pozwala mi na ocenę i odn...            342
#
#         liczba_sl_rawer
# 30196               614
# 43099               566
# 125034              336

# %%
ag.sort_values('date_', ascending=False).head(5)
# Out:
#           author_final  liczba_sl_raw  date_
# 1568    Stanisław Stec         477862   1368
# 1319   Mirosław Pawlak         203379   1134
# 1466   Romuald Ajchler         401879   1120
# 668          Jan Kulas         547001   1101
# 162   Andrzej Szlachta         242306    982

# %%
ag.sort_values('liczba_sl_raw', ascending=False).head(5)
# Out:
#              author_final  liczba_sl_raw  date_
# 668             Jan Kulas         547001   1101
# 914            Józef Zych         514652    878
# 797      Jerzy Jaskiernia         481512    658
# 1568       Stanisław Stec         477862   1368
# 1674  Tadeusz Tomaszewski         412781    917

# %%
ag[ag.author_final=='Krystyna Pawłowicz']
# Out:
#            author_final  liczba_sl_raw  date_
# 984  Krystyna Pawłowicz          41668    111

# %%
ag[ag.author_final=='Donald Tusk']
# Out:
#     author_final  liczba_sl_raw  date_
# 386  Donald Tusk          48473     47

# %%
ag[ag.author_final=='Janusz Korwin-Mikke']
# Out:
#             author_final  liczba_sl_raw  date_
# 727  Janusz Korwin-Mikke          87185    213

# %% [markdown]
# ## Budowa modeli dedykowanych poszczególnym posłom
#
# Czy wypowiedzi są podobne?

# %%
JK = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Jan Kulas'])
JZ = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Józef Zych'])
JJ = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Jerzy Jaskiernia'])
SS = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Stanisław Stec'])
TT = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Tadeusz Tomaszewski'])
KP = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Krystyna Pawłowicz'])
DT = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Donald Tusk'])
JKM = ' '.join(sp_joined['speech_raw'][sp_joined.author_final=='Janusz Korwin-Mikke'])

# %%
model_JK = ng_models.ng_models(1, JK)
model_JZ = ng_models.ng_models(1, JZ)
model_JJ = ng_models.ng_models(1, JJ)
model_SS = ng_models.ng_models(1, SS)
model_TT = ng_models.ng_models(1, TT)
model_KP = ng_models.ng_models(1, KP)
model_DT = ng_models.ng_models(1, DT)
model_JKM = ng_models.ng_models(1, JKM)

# %%
summary_table = pd.DataFrame()
summary_table['Zdanie']=['Zapewniam państwa, że jestem uczciwym politykiem', 
                        'Lew czarownica i stara szafa',
                        'Zupełnie przypadkowy układ pięciu słów',
                        'Panie ministrze proszę o wysłuchanie',
                        'Polskie rolnictwo rozwija się szybko i ma się dobrze',
                        'Demokracja jest najlepszym systemem politycznym',
                        'Jestem najlepszym kandydatem na prezydenta',
                        'Dla porównania zdanie długie o polityce o ustawie dotyczące zagadnień istotnych, które każdy poseł wypowiedzieć może',
                        'wysoka izbo']

# %%
summary_table['JK'] = summary_table['Zdanie'].apply(model_JK.perplexity).round()
summary_table['JZ'] = summary_table['Zdanie'].apply(model_JZ.perplexity).round()
summary_table['JJ'] = summary_table['Zdanie'].apply(model_JJ.perplexity).round()
summary_table['SS'] = summary_table['Zdanie'].apply(model_SS.perplexity).round()
summary_table['TT'] = summary_table['Zdanie'].apply(model_TT.perplexity).round()
summary_table['KP'] = summary_table['Zdanie'].apply(model_KP.perplexity).round()
summary_table['DT'] = summary_table['Zdanie'].apply(model_DT.perplexity).round()
summary_table['JKM'] = summary_table['Zdanie'].apply(model_JKM.perplexity).round()

# %%
summary_table.set_index('Zdanie').sort_values('JK')
# Out:
#                                                           JK        JZ  \
# Zdanie
# Polskie rolnictwo rozwija się szybko i ma się d...   34105.0   20462.0
# Dla porównania zdanie długie o polityce o ustaw...   50006.0   35541.0
# Jestem najlepszym kandydatem na prezydenta           99408.0  132733.0
# Panie ministrze proszę o wysłuchanie                106038.0  148993.0
# Zapewniam państwa, że jestem uczciwym politykiem    113538.0   97468.0
# Demokracja jest najlepszym systemem politycznym     214038.0  193570.0
# Zupełnie przypadkowy układ pięciu słów              380378.0  212971.0
# Lew czarownica i stara szafa                        401953.0  227390.0
# wysoka izbo                                         764867.0  962083.0
#
#                                                           JJ        SS  \
# Zdanie
# Polskie rolnictwo rozwija się szybko i ma się d...   37629.0   31977.0
# Dla porównania zdanie długie o polityce o ustaw...   41564.0   47523.0
# Jestem najlepszym kandydatem na prezydenta          109267.0  119376.0
# Panie ministrze proszę o wysłuchanie                126456.0   78030.0
# Zapewniam państwa, że jestem uczciwym politykiem    121845.0  102566.0
# Demokracja jest najlepszym systemem politycznym     178889.0  224905.0
# Zupełnie przypadkowy układ pięciu słów              237004.0  189810.0
# Lew czarownica i stara szafa                        283444.0  263432.0
# wysoka izbo                                         184906.0  490392.0
#
#                                                           TT        KP  \
# Zdanie
# Polskie rolnictwo rozwija się szybko i ma się d...   31389.0   22073.0
# Dla porównania zdanie długie o polityce o ustaw...   47219.0   17246.0
# Jestem najlepszym kandydatem na prezydenta          170145.0   38557.0
# Panie ministrze proszę o wysłuchanie                134142.0   35545.0
# Zapewniam państwa, że jestem uczciwym politykiem    121945.0   31829.0
# Demokracja jest najlepszym systemem politycznym     163560.0   49056.0
# Zupełnie przypadkowy układ pięciu słów              241681.0   60448.0
# Lew czarownica i stara szafa                        252835.0   61746.0
# wysoka izbo                                         511771.0  253445.0
#
#                                                           DT       JKM
# Zdanie
# Polskie rolnictwo rozwija się szybko i ma się d...   18614.0   18503.0
# Dla porównania zdanie długie o polityce o ustaw...   15730.0   23583.0
# Jestem najlepszym kandydatem na prezydenta           51243.0   81624.0
# Panie ministrze proszę o wysłuchanie                 42010.0   77749.0
# Zapewniam państwa, że jestem uczciwym politykiem     34920.0   62211.0
# Demokracja jest najlepszym systemem politycznym      51201.0   82070.0
# Zupełnie przypadkowy układ pięciu słów               63054.0  106223.0
# Lew czarownica i stara szafa                         64625.0  108245.0
# wysoka izbo                                         169064.0  121815.0

# %%
model_JJ.model_dict['demokracja']
# Out:
# ['pośrednia', 'przez', 'przez', 'pośrednia', '-']

# %% [markdown]
# ## Tworzenie najbardziej prawdopodobnego zdania
